# %%
import matplotlib.pyplot as pp
import pycbc.noise
import pycbc.psd
import pycbc.filter
from pycbc.waveform import get_td_waveform
from pycbc.waveform import get_fd_waveform
import numpy as np
from pycbc.vetoes import power_chisq
from pycbc.events.ranking import newsnr
import pandas as pd
from pycbc.filter import sigma
import h5py
from pycbc.types import timeseries
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1

# %%
def gen_noise(psd_need):
    
    # The color of the noise matches a PSD which you provide
    flow = 30.0
    delta_f = 1.0 / 16
    flen = int(2048 / delta_f) + 1
    psd = pycbc.psd.aLIGOZeroDetHighPower(flen, delta_f, flow)

    if (psd_need == True) :
        pp.plot(psd.sample_frequencies,psd.data)
        pp.loglog()
        pp.xlim(30,2000)
        pp.ylabel('$Strain^2 / Hz$')
        pp.xlabel('Frequency (Hz)')
        pp.show()


    # Generate 512 seconds of noise at 4096 Hz
    delta_t = 1.0 / 4096
    tsamples = int(32/ delta_t)
    ts = pycbc.noise.gaussian.noise_from_psd(tsamples,delta_t, psd, seed=127)
    
    
    #plotting noise 
#     pp.plot(ts.sample_times, ts)
#     pp.ylabel('Strain')
#     pp.xlabel('Time (simport numpy as np

#     pp.show()
    

    return ts

# %%
def gen_waveform(model,m1,m2,s1z,s2z,distance,time,l):
    
    from pycbc.detector import Detector
    from pycbc.waveform import get_td_waveform


   
    ra = 1.7
    dec = 1.7
    pol = 0.2
    inclination_1 = 0




    # We can calcualate the antenna pattern for Hanford at
    # the specific sky location
    d = Detector("H1")

    # We get back the fp and fc antenna pattern weights.
    fp, fc = d.antenna_pattern(ra, dec, pol, time)
    #print("fp={}, fc={}".format(fp, fc))

    # These factors allow us to project a signal into what the detector would observe
    # IMRPhenomPv2
    # Generate the waveform for the BNS merger
    hp_1, hc_1 = get_td_waveform(approximant=model,
                             mass1=m1, mass2=m2,spin1z=s1z,spin2z=s2z,
                             distance=distance, inclination=inclination_1,
                             delta_t=1.0/4096, f_lower=30)

    ## Apply the factors to get the detector frame strain
    ht_1 = fp * hp_1 + fc * hc_1
    
    
#     pp.plot(ht_1.sample_times, ht_1, label=l)
#     pp.legend()
#     pp.ylabel('Strain')
#     pp.xlabel('Time')
#     pp.grid()
#     pp.show()
    
    
    
    return ht_1

# %%
def overlap(ht_1,ht_2,buffer):

    if len(ht_1) < len(ht_2):
        ht_small, ht_big = ht_1, ht_2
    else:
        ht_small, ht_big = ht_2, ht_1

    dt = ht_small.delta_t
   
    
    # make buffer int multiple of dt
    buffer = np.round(buffer*ht_big.sample_rate)/ht_big.sample_rate
    
    
    # elongate the long template to accomodate enough space on left
    ht_big.resize(len(ht_big)+int(buffer*ht_big.sample_rate))
#     pp.plot(ht_big.sample_times,ht_big)
#     pp.show()
    
    # match small template
    ht_small.resize(len(ht_big))
#     pp.plot(ht_small.sample_times,ht_small)
#     pp.show()
    
    
    # correct the position after resizing
    ht_big = ht_big.cyclic_time_shift(buffer)
#     pp.plot(ht_big.sample_times,ht_big)
#     pp.show()
    
    #Shifting the merger time
    ht_small = ht_small.cyclic_time_shift(ht_small.start_time-ht_big.start_time-buffer)
#     pp.plot(ht_small.sample_times,ht_small)
#     pp.show()
    
    #Equating the start time of both signals
    ht_small.start_time = ht_big.start_time
   
    
    # resample to original sample rate
    ht_big = ht_big.resample(dt)
    ht_small = ht_small.resample(dt)
    
    

    #Combining the signals
    ht_total = ht_small + ht_big
#     pp.plot(ht_total.sample_times,ht_total)
#     pp.show()
    return ht_total,ht_2

# %%
def inject(ht_total,ts):
    
    #Resizing the signal
    ht_total.resize(len(ts)) 
    
    #Equating the start time
    ht_total.start_time = ts.start_time
    
    #Injecting signal into noise
    ts = ts.add_into(ht_total) 
    
    #plotting the result
#     pp.plot(ts.sample_times, ts)
#     pp.xlabel('Time(s)')
#     pp.ylabel('Strain')
#     pp.grid()
#     pp.show()
    
    return ts

# %%
def psd_data(conditioned):

    from pycbc.psd import interpolate, inverse_spectrum_truncation
    # Estimate the power spectral density

    # We use 4 second samples of our time series in Welch method.
    psd = conditioned.psd(4)

    # Now that we have the psd we need to interpolate it to match our data
    # and then limit the filter length of 1 / PSD. After this, we can
    # directly use this PSD to filter the data in a controlled manner

    psd = interpolate(psd, conditioned.delta_f)

    # 1/PSD will now act as a filter with an effective length of 4 seconds
    # Since the data has been highpassed above 30 Hz, and will have low values
    # below this we need to informat the function to not include frequencies
    # below this frequency. 
    psd = inverse_spectrum_truncation(psd, int(4 * conditioned.sample_rate),
                                      low_frequency_cutoff=30)

#     pp.loglog(psd.sample_frequencies, psd)
#     pp.ylabel('$Strain^2 / Hz$')
#     pp.xlabel('Frequency (Hz)')
#     pp.xlim(30, 1024)
    
    return psd

# %%
def gen_template(model,m1,m2,s1z,s2z,conditioned):
    
    from pycbc.detector import Detector
    from pycbc.waveform import get_td_waveform

    
    ra = 1.7
    dec = 1.7
    pol = 0.2
    inclination_1 = 0
    time=0.0



    # We can calcualate the antenna pattern for Hanford at
    # the specific sky location
    d = Detector("H1")

    # We get back the fp and fc antenna pattern weights.
    fp, fc = d.antenna_pattern(ra, dec, pol, time)
    
    
    
    
    hp, hc = get_td_waveform(approximant=model,
                     mass1=m1,
                     mass2=m2,spin1z=s1z,spin2z=s2z,
                     delta_t=conditioned.delta_t,
                     f_lower=30)
    
    
    ht_template = fp * hp + fc * hc
    
    #Resizing the template to match data
    ht_template.resize(len(conditioned))
    
    #Time shift 
    template = ht_template.cyclic_time_shift(ht_template.start_time)
    
   
    return template

# %%
def gen_SNR(template,conditioned,psd):
    from pycbc.filter import matched_filter
    import numpy

    snr = matched_filter(template, conditioned,
                         psd=psd, low_frequency_cutoff=30)



    # The `matched_filter` function actually returns a 'complex' SNR.
    # What that means is that the real portion correponds to the SNR
    # associated with directly filtering the template with the data.
    # The imaginary portion corresponds to filtering with a template that
    # is 90 degrees out of phase. Since the phase of a signal may be 
    # anything, we choose to maximize over the phase of the signal.

   
    peak = abs(snr).numpy().argmax()
    snrpc= snr[peak]
    snrp = abs(snr[peak])
    time = snr.sample_times[peak]
   
    
    return snr,time,peak,snrpc,snrp

# %%
def gen_chisquare(temp,data,m_1,m_2,s_1,s_2,psd):
    
    n =int(0.72*pycbc.pnutils.get_freq('fSEOBNRv4Peak',m_1,m_2,s_1,s_2)**0.7)
    
    chisq = power_chisq(temp, data, n, psd=psd, low_frequency_cutoff=30.0)

    # convert to a reduced chisq
    chisq /= (n * 2) - 2
    
    
    
    return chisq

# %%
def snr_chisq_nsnr(num_templates,data_templates,psd,data,model,s):

    template_info = []


    for i in range(num_templates):
        T1 = data_templates[i]

        S1,time_bns,index_peak_bns,C_snrp,old_snr_bns = gen_SNR(T1,data,psd)

        chisq_1 = gen_chisquare(T1,data,temp_bank[i][0],temp_bank[i][1],s,s,psd)
        chisq_val_bns = chisq_1[index_peak_bns]

        new_snr_bns = newsnr(abs(S1),chisq_1)

        snrp_bns = new_snr_bns[index_peak_bns]

        template_info.append([temp_bank[i][0],temp_bank[i][1],time_bns,old_snr_bns,snrp_bns,chisq_val_bns,C_snrp])

    return template_info

# %%
def recovery(data,n,data_templates,psd): 
    
  

    bbh_info =  snr_chisq_nsnr(n,data_templates,psd,data,'IMRPhenomPv2',0.8)

    
    

    info = {}
    for i in bbh_info:
        info.update({i[4] : [i[0],i[1],i[2],i[3],i[5],i[6]]})


    snrp_1 = max(info.keys())
    time_1 = info.get(max(info.keys()))[2]
    m1_1 = info.get(max(info.keys()))[0]
    m2_1 = info.get(max(info.keys()))[1]
    chi_sq_1 = info.get(max(info.keys()))[4]
    Comp_snrp = info.get(max(info.keys()))[5]

    print("The signal detected is due to the following masses ",m1_1,"M and ", m2_1, "M at time ", time_1, "seconds", " with new SNR value as", snrp_1, " and chi~square value as ", chi_sq_1 )
    
    
    return m1_1,m2_1,time_1,snrp_1,bbh_info,Comp_snrp

# %%
def align_sub(m1_1,m2_1,time_1,com_snrp,data,psd):   
    
    # The time, amplitude, and phase of the SNR peak tell us how to align
    # our proposed signal with the data.

    # Shift the template to the peak time
    dt = time_1 - data.start_time 
    
    
#     if (m1_1 >= 15 and m2_1 >= 15) : 
    temp_sub  = gen_template('IMRPhenomPv2',m1_1,m2_1,0.8,0.8,data)
        
#     else :
#         temp_sub = gen_template('TaylorF2',m1_1,m2_1,0.05,0.05,data)
        
     
    
    
    aligned = temp_sub.cyclic_time_shift(dt)

    # scale the template so that it would have SNR 1 in this data
    aligned /= sigma(aligned, psd=psd, low_frequency_cutoff=30.0)

    # Scale the template amplitude and phase to the peak value
    aligned = (aligned.to_frequencyseries() * com_snrp).to_timeseries()
    aligned.start_time = data.start_time

    
    subtracted = data - aligned
    
    psd2 = psd_data(subtracted)  

    
    return subtracted,psd2

# %%
data_templates = []
for i in range(200):
    T = timeseries.load_timeseries(f"Signals_BBH_BBH/signal{i}.hdf")
    data_templates.append(T)
    
    
temp_bank = pd.read_csv('Signals_BBH_BBH/Load_bbh_bbh.csv')
temp_bank = temp_bank.values.tolist()

# %%
for j in range(20):
    
    print("Recovery number:",j)
    print(' ')
    
    ts1 = timeseries.load_timeseries(f"Signals_BBH_BBH/Data_{j}.hdf")
    psd1 = psd_data(ts1)  
    mass_1,mass_2,time,snrp,total,j_snrp = recovery(ts1,200,data_templates,psd1)
    
    print(' ')


    for i in range(5):

        sub,psd_sub = align_sub(mass_1,mass_2,time,j_snrp,ts1,psd1)
        M1,M2,T,SP,Tot,k_snrp = recovery(sub,200,data_templates,psd_sub)
    #     pp.plot(sub.sample_times,sub)
    #     pp.xlim(1.6,2.0)
    #     pp.show()
        mass_1=M1
        mass_2=M2
        time=T
        snrp=SP
        j_snrp = k_snrp
        total.extend([[0,0,0,0,0,0]])
        total.extend(Tot)

        print(" ")
    print("-----------------------------------------------------------------------------------")
# Out:
# Recovery number: 0
#
# The signal detected is due to the following masses  23.68443329796192 M and  45.19735929776556 M at time  1.7998046875 seconds  with new SNR value as 20.855700887575527  and chi~square value as  14.087856782347105
#
# The signal detected is due to the following masses  23.180067561291544 M and  25.885465529111784 M at time  2.010986328125 seconds  with new SNR value as 55.66819813334718  and chi~square value as  1.0650320807460052
#
# The signal detected is due to the following masses  23.68443329796192 M and  45.19735929776556 M at time  1.7998046875 seconds  with new SNR value as 64.19455065547321  and chi~square value as  1.252923699266477
#
# The signal detected is due to the following masses  23.180067561291544 M and  25.885465529111784 M at time  2.010986328125 seconds  with new SNR value as 55.57943333615606  and chi~square value as  1.0745276325860555
#
# The signal detected is due to the following masses  23.68443329796192 M and  45.19735929776556 M at time  1.7998046875 seconds  with new SNR value as 64.20501001621551  and chi~square value as  1.252242544648492
#
# The signal detected is due to the following masses  23.180067561291544 M and  25.885465529111784 M at time  2.010986328125 seconds  with new SNR value as 55.57958994033021  and chi~square value as  1.0745199082451342
#
# -----------------------------------------------------------------------------------
# Recovery number: 1
#
# The signal detected is due to the following masses  32.99798661908729 M and  33.156682008651075 M at time  1.80029296875 seconds  with new SNR value as 29.761060914294628  and chi~square value as  7.402999301465543
#
# The signal detected is due to the following masses  20.52313260984448 M and  30.80491859622802 M at time  2.072021484375 seconds  with new SNR value as 44.82057981277346  and chi~square value as  1.8427575523230506
#
# The signal detected is due to the following masses  29.42030401386844 M and  38.26750070576747 M at time  1.800048828125 seconds  with new SNR value as 70.34408613137822  and chi~square value as  1.0821743459801325
#
# The signal detected is due to the following masses  22.14024231254922 M and  28.164417137090837 M at time  2.072021484375 seconds  with new SNR value as 50.87781145057546  and chi~square value as  1.3468873346596448
#
# The signal detected is due to the following masses  29.42030401386844 M and  38.26750070576747 M at time  1.800048828125 seconds  with new SNR value as 70.795472099262  and chi~square value as  1.0686238901804983
#
# The signal detected is due to the following masses  22.14024231254922 M and  28.164417137090837 M at time  2.072021484375 seconds  with new SNR value as 50.92067650165078  and chi~square value as  1.3440040392840187
#
# -----------------------------------------------------------------------------------
# Recovery number: 2
#
# The signal detected is due to the following masses  35.84144376989065 M and  35.61033868526971 M at time  1.799560546875 seconds  with new SNR value as 23.089870153576445  and chi~square value as  13.296122606099685
#
# The signal detected is due to the following masses  16.35755426239158 M and  33.047904795330474 M at time  1.969970703125 seconds  with new SNR value as 23.025189709172587  and chi~square value as  4.974796129447006
#
# The signal detected is due to the following masses  33.72025832461511 M and  35.96830033837324 M at time  1.7998046875 seconds  with new SNR value as 58.68927726776659  and chi~square value as  1.8713860912827103
#
# The signal detected is due to the following masses  17.417103976158675 M and  31.156061854534144 M at time  1.969970703125 seconds  with new SNR value as 47.79522462382521  and chi~square value as  1.2466047428976512
#
# The signal detected is due to the following masses  30.802828918076333 M and  39.3477676161538 M at time  1.7998046875 seconds  with new SNR value as 68.50075003861058  and chi~square value as  1.3366819812769528
#
# The signal detected is due to the following masses  17.417103976158675 M and  31.156061854534144 M at time  1.969970703125 seconds  with new SNR value as 48.83734714386202  and chi~square value as  1.1874573585099364
#
# -----------------------------------------------------------------------------------
# Recovery number: 3
#
# The signal detected is due to the following masses  26.719655274434487 M and  32.09983709242775 M at time  1.7998046875 seconds  with new SNR value as 23.05930414344094  and chi~square value as  9.697943944735032
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  2.048583984375 seconds  with new SNR value as 46.38577754473655  and chi~square value as  1.4426053688080942
#
# The signal detected is due to the following masses  25.27943534497583 M and  33.38423755176102 M at time  1.800048828125 seconds  with new SNR value as 59.88815799456609  and chi~square value as  1.1864785605035288
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  2.048583984375 seconds  with new SNR value as 50.691268657425894  and chi~square value as  1.129306107035103
#
# The signal detected is due to the following masses  25.27943534497583 M and  33.38423755176102 M at time  1.800048828125 seconds  with new SNR value as 59.94418865186796  and chi~square value as  1.182942239121416
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  2.048583984375 seconds  with new SNR value as 50.691541008841405  and chi~square value as  1.1293128936586234
#
# -----------------------------------------------------------------------------------
# Recovery number: 4
#
# The signal detected is due to the following masses  30.33049181208582 M and  34.42974714352356 M at time  1.7998046875 seconds  with new SNR value as 17.909511403793402  and chi~square value as  19.55429258223193
#
# The signal detected is due to the following masses  20.17974483947457 M and  34.46869602429071 M at time  1.960205078125 seconds  with new SNR value as 52.267581202586356  and chi~square value as  1.3790337460115571
#
# The signal detected is due to the following masses  31.232626449938994 M and  33.74905378514626 M at time  1.7998046875 seconds  with new SNR value as 64.21741360863646  and chi~square value as  1.342829463305054
#
# The signal detected is due to the following masses  20.07747900682758 M and  34.59069240345681 M at time  1.960205078125 seconds  with new SNR value as 54.19965055344638  and chi~square value as  1.2698529879175553
#
# The signal detected is due to the following masses  31.232626449938994 M and  33.74905378514626 M at time  1.7998046875 seconds  with new SNR value as 64.77622248910626  and chi~square value as  1.3153432154788618
#
# The signal detected is due to the following masses  20.07747900682758 M and  34.59069240345681 M at time  1.960205078125 seconds  with new SNR value as 54.17672080450644  and chi~square value as  1.2716129661049342
#
# -----------------------------------------------------------------------------------
# Recovery number: 5
#
# The signal detected is due to the following masses  28.10118841467183 M and  34.99553691988425 M at time  3.80029296875 seconds  with new SNR value as 23.07086280302917  and chi~square value as  10.574350797370904
#
# The signal detected is due to the following masses  12.985894581708305 M and  35.8024558185121 M at time  4.001708984375 seconds  with new SNR value as 27.681240086429572  and chi~square value as  2.983183759166648
#
# The signal detected is due to the following masses  24.576048649564328 M and  41.415794260170806 M at time  3.800048828125 seconds  with new SNR value as 52.75932023006725  and chi~square value as  2.1381687152075837
#
# The signal detected is due to the following masses  13.77007924586147 M and  34.12043303504039 M at time  4.001708984375 seconds  with new SNR value as 41.840558273479544  and chi~square value as  1.3085671844099829
#
# The signal detected is due to the following masses  26.73264743666203 M and  38.39110782443654 M at time  3.800048828125 seconds  with new SNR value as 68.17554461537388  and chi~square value as  0.9267774905502464
#
# The signal detected is due to the following masses  13.77007924586147 M and  34.12043303504039 M at time  4.001708984375 seconds  with new SNR value as 46.72231523578902  and chi~square value as  0.9667001221461825
#
# -----------------------------------------------------------------------------------
# Recovery number: 6
#
# The signal detected is due to the following masses  26.719655274434487 M and  32.09983709242775 M at time  1.800048828125 seconds  with new SNR value as 16.763049247590367  and chi~square value as  17.22649322863601
#
# The signal detected is due to the following masses  19.725216908321656 M and  35.994361588648204 M at time  1.940185546875 seconds  with new SNR value as 53.09647234488585  and chi~square value as  1.2988460689780497
#
# The signal detected is due to the following masses  25.62331434004996 M and  33.94247066523713 M at time  1.800048828125 seconds  with new SNR value as 60.03701806598681  and chi~square value as  1.2219231648423718
#
# The signal detected is due to the following masses  19.725216908321656 M and  35.994361588648204 M at time  1.940185546875 seconds  with new SNR value as 57.2116923611958  and chi~square value as  1.0335995049356077
#
# The signal detected is due to the following masses  25.62331434004996 M and  33.94247066523713 M at time  1.800048828125 seconds  with new SNR value as 60.01364023063583  and chi~square value as  1.2238939852998028
#
# The signal detected is due to the following masses  19.725216908321656 M and  35.994361588648204 M at time  1.940185546875 seconds  with new SNR value as 57.219721935267145  and chi~square value as  1.033058518770505
#
# -----------------------------------------------------------------------------------
# Recovery number: 7
#
# The signal detected is due to the following masses  35.24740591141864 M and  39.0216015317969 M at time  3.800048828125 seconds  with new SNR value as 30.725047960931388  and chi~square value as  8.885561184925214
#
# The signal detected is due to the following masses  13.217416158940424 M and  27.55098414107529 M at time  4.04443359375 seconds  with new SNR value as 40.35586541639539  and chi~square value as  1.1641071831023149
#
# The signal detected is due to the following masses  34.854543642768 M and  39.24636481278238 M at time  3.800048828125 seconds  with new SNR value as 79.93299055605229  and chi~square value as  0.9279812629603951
#
# The signal detected is due to the following masses  11.355086958488185 M and  32.912961834772744 M at time  4.044189453125 seconds  with new SNR value as 43.014414663315485  and chi~square value as  0.9487507532547803
#
# The signal detected is due to the following masses  34.854543642768 M and  39.24636481278238 M at time  3.800048828125 seconds  with new SNR value as 79.92714589160647  and chi~square value as  0.920674305494441
#
# The signal detected is due to the following masses  11.355086958488185 M and  32.912961834772744 M at time  4.044189453125 seconds  with new SNR value as 43.029617000827706  and chi~square value as  0.9492457473536695
#
# -----------------------------------------------------------------------------------
# Recovery number: 8
#
# The signal detected is due to the following masses  26.512332370398383 M and  39.62927841886885 M at time  1.799560546875 seconds  with new SNR value as 30.34575932800541  and chi~square value as  6.448522556234738
#
# The signal detected is due to the following masses  19.55344124514024 M and  30.4332331329238 M at time  2.087158203125 seconds  with new SNR value as 51.74705968296357  and chi~square value as  1.1953382333211837
#
# The signal detected is due to the following masses  28.633094812278152 M and  36.03282598616901 M at time  1.7998046875 seconds  with new SNR value as 65.93820970895172  and chi~square value as  1.2256156814331896
#
# The signal detected is due to the following masses  19.55344124514024 M and  30.4332331329238 M at time  2.087158203125 seconds  with new SNR value as 53.67977630177037  and chi~square value as  1.0661953404758286
#
# The signal detected is due to the following masses  28.633094812278152 M and  36.03282598616901 M at time  1.7998046875 seconds  with new SNR value as 65.97161933614316  and chi~square value as  1.2237282440564512
#
# The signal detected is due to the following masses  19.55344124514024 M and  30.4332331329238 M at time  2.087158203125 seconds  with new SNR value as 53.680615256247506  and chi~square value as  1.0661387712753496
#
# -----------------------------------------------------------------------------------
# Recovery number: 9
#
# The signal detected is due to the following masses  33.57753583790981 M and  42.634477972200926 M at time  1.79931640625 seconds  with new SNR value as 20.51507177181946  and chi~square value as  19.569330001140695
#
# The signal detected is due to the following masses  22.14024231254922 M and  28.164417137090837 M at time  1.915283203125 seconds  with new SNR value as 23.856357951962732  and chi~square value as  5.693349516644149
#
# The signal detected is due to the following masses  29.652389327349283 M and  45.781817051565454 M at time  1.799560546875 seconds  with new SNR value as 64.30094191597664  and chi~square value as  1.6653954777294455
#
# The signal detected is due to the following masses  20.52313260984448 M and  30.80491859622802 M at time  1.915283203125 seconds  with new SNR value as 48.07301781673738  and chi~square value as  1.5404476642473297
#
# The signal detected is due to the following masses  29.652389327349283 M and  45.781817051565454 M at time  1.799560546875 seconds  with new SNR value as 76.97006712042442  and chi~square value as  1.0472811945710294
#
# The signal detected is due to the following masses  20.52313260984448 M and  30.80491859622802 M at time  1.915283203125 seconds  with new SNR value as 48.71546255905924  and chi~square value as  1.495383132645989
#
# -----------------------------------------------------------------------------------
# Recovery number: 10
#
# The signal detected is due to the following masses  27.7600332963294 M and  39.89946356595272 M at time  1.7998046875 seconds  with new SNR value as 18.847355897685862  and chi~square value as  20.010570052269887
#
# The signal detected is due to the following masses  19.685591184854857 M and  29.96769837605501 M at time  1.938720703125 seconds  with new SNR value as 42.00769573618542  and chi~square value as  1.9010454641115584
#
# The signal detected is due to the following masses  25.999261373842657 M and  41.89346112821609 M at time  1.7998046875 seconds  with new SNR value as 62.489349565022344  and chi~square value as  1.4486869104561386
#
# The signal detected is due to the following masses  19.55344124514024 M and  30.4332331329238 M at time  1.938720703125 seconds  with new SNR value as 50.0003383733394  and chi~square value as  1.3100607590093585
#
# The signal detected is due to the following masses  25.999261373842657 M and  41.89346112821609 M at time  1.7998046875 seconds  with new SNR value as 68.03240683389957  and chi~square value as  1.1608023276581347
#
# The signal detected is due to the following masses  19.55344124514024 M and  30.4332331329238 M at time  1.938720703125 seconds  with new SNR value as 50.12562905607749  and chi~square value as  1.3020523083948055
#
# -----------------------------------------------------------------------------------
# Recovery number: 11
#
# The signal detected is due to the following masses  28.351868545652835 M and  48.450129887519616 M at time  1.799560546875 seconds  with new SNR value as 33.216149030906934  and chi~square value as  6.913707918124211
#
# The signal detected is due to the following masses  25.764543191780856 M and  25.674089622524225 M at time  2.089111328125 seconds  with new SNR value as 52.28868454239368  and chi~square value as  1.4334235979493941
#
# The signal detected is due to the following masses  29.652389327349283 M and  45.781817051565454 M at time  1.799560546875 seconds  with new SNR value as 77.05678158756723  and chi~square value as  1.0506347344455558
#
# The signal detected is due to the following masses  23.30133982807166 M and  28.537510122207188 M at time  2.089111328125 seconds  with new SNR value as 56.1142838395286  and chi~square value as  1.1816725099836092
#
# The signal detected is due to the following masses  29.652389327349283 M and  45.781817051565454 M at time  1.799560546875 seconds  with new SNR value as 78.04871196336039  and chi~square value as  1.0075967174722473
#
# The signal detected is due to the following masses  23.30133982807166 M and  28.537510122207188 M at time  2.089111328125 seconds  with new SNR value as 56.010111602874595  and chi~square value as  1.1887489895526335
#
# -----------------------------------------------------------------------------------
# Recovery number: 12
#
# The signal detected is due to the following masses  34.22649443088822 M and  38.27259742961444 M at time  1.800048828125 seconds  with new SNR value as 25.93780262352233  and chi~square value as  11.773557500233508
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  1.989013671875 seconds  with new SNR value as 31.008655769596764  and chi~square value as  2.7976752811142402
#
# The signal detected is due to the following masses  34.854543642768 M and  39.24636481278238 M at time  1.7998046875 seconds  with new SNR value as 73.37595434546898  and chi~square value as  1.249216686614901
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  1.989013671875 seconds  with new SNR value as 49.31582529450479  and chi~square value as  1.0775080339245207
#
# The signal detected is due to the following masses  34.854543642768 M and  39.24636481278238 M at time  1.7998046875 seconds  with new SNR value as 75.78414761667825  and chi~square value as  1.1293106288005614
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  1.989013671875 seconds  with new SNR value as 49.661929021753274  and chi~square value as  1.053255820537735
#
# -----------------------------------------------------------------------------------
# Recovery number: 13
#
# The signal detected is due to the following masses  30.56103008455672 M and  42.18647343018771 M at time  3.7998046875 seconds  with new SNR value as 30.802567815214484  and chi~square value as  7.748314438375248
#
# The signal detected is due to the following masses  17.1770866804908 M and  28.262697363104586 M at time  4.105224609375 seconds  with new SNR value as 50.91787287571364  and chi~square value as  0.9400176201352374
#
# The signal detected is due to the following masses  30.56103008455672 M and  42.18647343018771 M at time  3.7998046875 seconds  with new SNR value as 74.77597138575958  and chi~square value as  0.7913203515341429
#
# The signal detected is due to the following masses  17.1770866804908 M and  28.262697363104586 M at time  4.105224609375 seconds  with new SNR value as 50.985442800332486  and chi~square value as  0.923062779692454
#
# The signal detected is due to the following masses  30.56103008455672 M and  42.18647343018771 M at time  3.7998046875 seconds  with new SNR value as 74.7734038740542  and chi~square value as  0.7915312553981124
#
# The signal detected is due to the following masses  17.1770866804908 M and  28.262697363104586 M at time  4.105224609375 seconds  with new SNR value as 50.985547624084404  and chi~square value as  0.9230529256185032
#
# -----------------------------------------------------------------------------------
# Recovery number: 14
#
# The signal detected is due to the following masses  32.84078646130974 M and  37.486560495336285 M at time  3.800048828125 seconds  with new SNR value as 24.333322638406074  and chi~square value as  10.970641990230776
#
# The signal detected is due to the following masses  12.985894581708305 M and  35.8024558185121 M at time  4.039794921875 seconds  with new SNR value as 32.20319916301717  and chi~square value as  2.3804942885867018
#
# The signal detected is due to the following masses  32.62286988053833 M and  39.27984049158833 M at time  3.7998046875 seconds  with new SNR value as 71.85428875637355  and chi~square value as  1.2079262153613717
#
# The signal detected is due to the following masses  12.985894581708305 M and  35.8024558185121 M at time  4.039794921875 seconds  with new SNR value as 47.40112576267271  and chi~square value as  0.6582750999569915
#
# The signal detected is due to the following masses  30.56103008455672 M and  42.18647343018771 M at time  3.7998046875 seconds  with new SNR value as 75.4715595176085  and chi~square value as  1.0196768421180962
#
# The signal detected is due to the following masses  12.985894581708305 M and  35.8024558185121 M at time  4.039794921875 seconds  with new SNR value as 47.627775425246256  and chi~square value as  0.6981894709698349
#
# -----------------------------------------------------------------------------------
# Recovery number: 15
#
# The signal detected is due to the following masses  36.77098370723194 M and  36.71313461760915 M at time  3.7998046875 seconds  with new SNR value as 23.174475429427826  and chi~square value as  12.855936980964255
#
# The signal detected is due to the following masses  11.743221784324982 M and  26.014229070259027 M at time  3.910888671875 seconds  with new SNR value as 38.679234778619815  and chi~square value as  1.1271562708001779
#
# The signal detected is due to the following masses  36.77098370723194 M and  36.71313461760915 M at time  3.7998046875 seconds  with new SNR value as 79.64799199886252  and chi~square value as  0.9300450251682107
#
# The signal detected is due to the following masses  11.743221784324982 M and  26.014229070259027 M at time  3.910888671875 seconds  with new SNR value as 40.74264445999856  and chi~square value as  0.9244127940263364
#
# The signal detected is due to the following masses  36.77098370723194 M and  36.71313461760915 M at time  3.7998046875 seconds  with new SNR value as 79.75272239731493  and chi~square value as  0.9016529025729703
#
# The signal detected is due to the following masses  11.743221784324982 M and  26.014229070259027 M at time  3.910888671875 seconds  with new SNR value as 40.75768614274541  and chi~square value as  0.9238252023904695
#
# -----------------------------------------------------------------------------------
# Recovery number: 16
#
# The signal detected is due to the following masses  29.42030401386844 M and  38.26750070576747 M at time  1.800048828125 seconds  with new SNR value as 32.80934848400196  and chi~square value as  5.83268352159198
#
# The signal detected is due to the following masses  19.55344124514024 M and  30.4332331329238 M at time  2.114501953125 seconds  with new SNR value as 51.00881017024038  and chi~square value as  1.1263552130083565
#
# The signal detected is due to the following masses  27.7600332963294 M and  39.89946356595272 M at time  1.800048828125 seconds  with new SNR value as 67.6373173303135  and chi~square value as  1.2276432401528792
#
# The signal detected is due to the following masses  19.685591184854857 M and  29.96769837605501 M at time  2.114501953125 seconds  with new SNR value as 52.964659503975035  and chi~square value as  1.0008790172500772
#
# The signal detected is due to the following masses  27.7600332963294 M and  39.89946356595272 M at time  1.800048828125 seconds  with new SNR value as 69.73399463861587  and chi~square value as  1.1034248033401577
#
# The signal detected is due to the following masses  19.685591184854857 M and  29.96769837605501 M at time  2.114501953125 seconds  with new SNR value as 52.95063569124199  and chi~square value as  1.002006436497985
#
# -----------------------------------------------------------------------------------
# Recovery number: 17
#
# The signal detected is due to the following masses  26.889871702798448 M and  42.42262570836771 M at time  1.7998046875 seconds  with new SNR value as 18.337465976346888  and chi~square value as  19.686902331941777
#
# The signal detected is due to the following masses  25.62331434004996 M and  33.94247066523713 M at time  1.951171875 seconds  with new SNR value as 45.096509480020195  and chi~square value as  2.366011948693139
#
# The signal detected is due to the following masses  30.416155164849 M and  38.16423643513559 M at time  1.7998046875 seconds  with new SNR value as 69.76143440988244  and chi~square value as  1.178769028386474
#
# The signal detected is due to the following masses  24.100144000598085 M and  36.8012403431524 M at time  1.950927734375 seconds  with new SNR value as 58.572152260045804  and chi~square value as  1.2925360754641086
#
# The signal detected is due to the following masses  30.416155164849 M and  38.16423643513559 M at time  1.7998046875 seconds  with new SNR value as 71.71282803113624  and chi~square value as  1.0609934976364366
#
# The signal detected is due to the following masses  24.100144000598085 M and  36.8012403431524 M at time  1.950927734375 seconds  with new SNR value as 58.78812141349914  and chi~square value as  1.2790893548602145
#
# -----------------------------------------------------------------------------------
# Recovery number: 18
#
# The signal detected is due to the following masses  33.991405503572246 M and  38.99436947281287 M at time  1.7998046875 seconds  with new SNR value as 27.144945337781035  and chi~square value as  10.70349860881645
#
# The signal detected is due to the following masses  17.54760237024156 M and  39.06905833486464 M at time  2.056396484375 seconds  with new SNR value as 48.12530784059238  and chi~square value as  1.5365483479717548
#
# The signal detected is due to the following masses  29.652389327349283 M and  45.781817051565454 M at time  1.799560546875 seconds  with new SNR value as 76.9365121317383  and chi~square value as  1.0626340814782882
#
# The signal detected is due to the following masses  17.54760237024156 M and  39.06905833486464 M at time  2.056396484375 seconds  with new SNR value as 48.11792588567797  and chi~square value as  1.5405071128304768
#
# The signal detected is due to the following masses  29.652389327349283 M and  45.781817051565454 M at time  1.799560546875 seconds  with new SNR value as 76.81602517259888  and chi~square value as  1.0690101550894904
#
# The signal detected is due to the following masses  17.54760237024156 M and  39.06905833486464 M at time  2.056396484375 seconds  with new SNR value as 48.11898049044115  and chi~square value as  1.5404229668945792
#
# -----------------------------------------------------------------------------------
# Recovery number: 19
#
# The signal detected is due to the following masses  32.2255547956399 M and  35.83047713927014 M at time  1.800048828125 seconds  with new SNR value as 24.00234890520894  and chi~square value as  12.45033829424399
#
# The signal detected is due to the following masses  18.115502136791925 M and  28.54803732727442 M at time  1.97900390625 seconds  with new SNR value as 35.19729133451923  and chi~square value as  2.407493081729979
#
# The signal detected is due to the following masses  30.416155164849 M and  38.16423643513559 M at time  1.800048828125 seconds  with new SNR value as 58.62186199535515  and chi~square value as  1.795238562502731
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  1.979248046875 seconds  with new SNR value as 40.23475819963119  and chi~square value as  1.8437077719011257
#
# The signal detected is due to the following masses  29.47172728654695 M and  40.01739810319423 M at time  1.800048828125 seconds  with new SNR value as 67.45644797425734  and chi~square value as  1.3186695942187898
#
# The signal detected is due to the following masses  17.328140218368773 M and  29.413600570693696 M at time  1.979248046875 seconds  with new SNR value as 46.49401237631771  and chi~square value as  1.3758833108629365
#
# -----------------------------------------------------------------------------------
