# %%
import matplotlib.pyplot as pp
import pycbc.noise
import pycbc.psd
import pycbc.filter
from pycbc.waveform import get_td_waveform
from pycbc.waveform import get_fd_waveform
import numpy as np
from pycbc.vetoes import power_chisq
from pycbc.events.ranking import newsnr
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1

# %% [markdown]
# # Generating noise and colouring it with provided PSD

# %%
def gen_noise(psd_need):
    
    # The color of the noise matches a PSD which you provide
    flow = 30.0
    delta_f = 1.0 / 16
    flen = int(2048 / delta_f) + 1
    psd = pycbc.psd.aLIGOZeroDetHighPower(flen, delta_f, flow)

    if (psd_need == True) :
        pp.plot(psd.sample_frequencies,psd.data)
        pp.loglog()
        pp.xlim(30,2000)
        pp.ylabel('$Strain^2 / Hz$')
        pp.xlabel('Frequency (Hz)')
        pp.show()


    # Generate 256 seconds of noise at 4096 Hz
    delta_t = 1.0 / 4096
    tsamples = int(256/ delta_t)
    ts = pycbc.noise.gaussian.noise_from_psd(tsamples,delta_t, psd, seed=127)
    
    
    #plotting noise 
    pp.plot(ts.sample_times, ts)
    pp.ylabel('Strain')
    pp.xlabel('Time (s)')
    pp.show()
    
#     pp.plot(stilde.sample_frequencies, stilde)
#     pp.ylabel('Strain')
#     pp.xlabel('Frequency (1/s)')
#     pp.show()
    
    return ts

noise = gen_noise(True)

# %% [markdown]
# # Generating Strain

# %%
def gen_waveform(model,m1,m2,s1z,s2z,distance,time,l):
    
    from pycbc.detector import Detector
    from pycbc.waveform import get_td_waveform


    distance_1 = distance
    ra = 1.7
    dec = 1.7
    pol = 0.2
    inclination_1 = 0




    # We can calcualate the antenna pattern for Hanford at
    # the specific sky location
    d = Detector("H1")

    # We get back the fp and fc antenna pattern weights.
    fp, fc = d.antenna_pattern(ra, dec, pol, time)
    print("fp={}, fc={}".format(fp, fc))

    # These factors allow us to project a signal into what the detector would observe
    # IMRPhenomPv2
    # Generate the waveform for the BNS merger
    hp_1, hc_1 = get_td_waveform(approximant=model,
                             mass1=m1, mass2=m2,spin1z=s1z,spin2z=s2z,
                             distance=distance_1, inclination=inclination_1,
                             delta_t=1.0/4096, f_lower=30)

    ## Apply the factors to get the detector frame strain
    ht_1 = fp * hp_1 + fc * hc_1
    
    
    pp.plot(ht_1.sample_times, ht_1, label=l)
    pp.legend()
    pp.ylabel('Strain')
    pp.xlabel('Time')
    pp.grid()
    pp.show()
    
    
    
    return ht_1

# generating BNS signal

h1_bns = gen_waveform('TaylorF2',1.4,1.4,0.5,0.5,200,0.0,"BNS")

pp.plot(h1_bns.sample_times, h1_bns, label='BNS')
pp.legend()
pp.xlim(-0.02,0.02)
pp.ylabel('Strain')
pp.xlabel('Time')
pp.grid()
pp.show()




h1_bbh = gen_waveform('IMRPhenomPv2',30,30,0.8,0.8,6000,0.0,"BBH")
# Out:
# fp=0.5494252193754385, fc=-0.5320202660769405
# fp=0.5494252193754385, fc=-0.5320202660769405

# %% [markdown]
# # Combining the Signals

# %%
def overlap(ht_1,ht_2,buffer):
    
    #Equal lengths of signals
    ht_2.resize(len(ht_1))
    
    #Shifting the merger time
    ht_2=ht_2.cyclic_time_shift(ht_2.end_time - buffer)
    
    #Equating the start time of both signals
    ht_2.start_time = ht_1.start_time
    
    #Combining the signals
    ht_total = ht_1 + ht_2

    #Ploting the signals
    pp.plot(ht_total.sample_times, ht_total, label='Overlapped')
    pp.legend()
    pp.ylabel('Strain')
    pp.xlabel('Time')
    pp.grid()
    pp.show()
    
    return ht_total,ht_2

ht_total,h1_bbh = overlap(h1_bns,h1_bbh,1)
print(ht_total.start_time)

signal_1_peak = ht_total.start_time * (-1)
# Out:
# -127.8

# %%
pp.plot(ht_total.sample_times, ht_total, label='Overlapped')
pp.xlim(-1.5,0.05)
#pp.ylim(-0.5*(10**-21),0.5*(10**-21))
pp.legend()
pp.ylabel('Strain')
pp.xlabel('Time')
pp.title('Overlapped Signal')
pp.grid()
pp.show()


print(ht_total.sample_times[abs(ht_total).numpy().argmax()])
# Out:
# -0.8085449218749972

# %% [markdown]
# # Injecting Strain into noise

# %%
def inject(ht_total,ts):
    
    #Resizing the signal
    ht_total.resize(len(ts)) 
    
    #Equating the start time
    ht_total.start_time = ts.start_time
    
    #Injecting signal into noise
    ts = ts.add_into(ht_total) 
    
    #plotting the result
    pp.plot(ts.sample_times, ts)
    pp.xlabel('Time(s)')
    pp.ylabel('Strain')
    pp.grid()
    pp.show()
    
    return ts 

ts1 = inject(ht_total,noise)
stilde=ts1.to_frequencyseries

signal_2_peak = signal_1_peak - 0.8085449218749972



print(signal_1_peak)
print(signal_2_peak)
# Out:
# 127.8
# 126.991455078

# %% [markdown]
# # Calculating the PSD

# %%
def psd_data(conditioned):

    from pycbc.psd import interpolate, inverse_spectrum_truncation
    # Estimate the power spectral density

    # We use 4 second samples of our time series in Welch method.
    psd = conditioned.psd(4)

    # Now that we have the psd we need to interpolate it to match our data
    # and then limit the filter length of 1 / PSD. After this, we can
    # directly use this PSD to filter the data in a controlled manner

    psd = interpolate(psd, conditioned.delta_f)

    # 1/PSD will now act as a filter with an effective length of 4 seconds
    # Since the data has been highpassed above 30 Hz, and will have low values
    # below this we need to informat the function to not include frequencies
    # below this frequency. 
    psd = inverse_spectrum_truncation(psd, int(4 * conditioned.sample_rate),
                                      low_frequency_cutoff=30)

    pp.loglog(psd.sample_frequencies, psd)
    pp.ylabel('$Strain^2 / Hz$')
    pp.xlabel('Frequency (Hz)')
    pp.xlim(30, 1024)
    
    return psd

psd1 = psd_data(ts1)

# %% [markdown]
# # Generating the Template

# %%
def gen_template(model,m1,m2,s1z,s2z,conditioned):
    
    
    
    hp, hc = get_td_waveform(approximant=model,
                     mass1=m1,
                     mass2=m2,spin1z=s1z,spin2z=s2z,
                     delta_t=conditioned.delta_t,
                     f_lower=30)
    
    #Resizing the template to match data
    hp.resize(len(conditioned))
    
    #Time shift 
    template = hp.cyclic_time_shift(hp.start_time)
    
    #plotting
    pp.plot(template.sample_times,template)
    pp.xlabel('Time(s)')
    pp.ylabel('Strain')
    pp.show()
    
    return template


template = gen_template('TaylorF2',1.4,1.4,0.5,0.5,ts1)



temp_BBH=gen_template('IMRPhenomPv2',30,30,0.8,0.8,ts1)

# %% [markdown]
# # Generating SNR time series

# %%
def gen_SNR(template,conditioned,psd):
    from pycbc.filter import matched_filter
    import numpy

    snr = matched_filter(template, conditioned,
                         psd=psd, low_frequency_cutoff=30)



    # The `matched_filter` function actually returns a 'complex' SNR.
    # What that means is that the real portion correponds to the SNR
    # associated with directly filtering the template with the data.
    # The imaginary portion corresponds to filtering with a template that
    # is 90 degrees out of phase. Since the phase of a signal may be 
    # anything, we choose to maximize over the phase of the signal.


    pp.figure(figsize=[10, 4])
    pp.plot(snr.sample_times, abs(snr))
    pp.ylabel('Signal-to-noise')
    pp.xlabel('Time (s)')
    

    peak = abs(snr).numpy().argmax()
    snrp = snr[peak]
    time = snr.sample_times[peak]

    print("We found a signal at {}s with SNR {}".format(time, 
                                                        abs(snrp)))
    return snr

snr1 = gen_SNR(template,ts1,psd1)

pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1,label='BNS')
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1,label='BNS')
pp.title('Matched Filtered SNR-(Template-BNS)')
pp.show()


pp.plot(snr1.sample_times, abs(snr1))
pp.ylabel('Signal-to-noise')
pp.xlabel('Time (s)')
pp.xlim(126,128)   
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Matched Filtered SNR-(Template-BNS)')
pp.show()




snr_BBH= gen_SNR(temp_BBH,ts1,psd1)

pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Matched Filtered SNR-(Template-BBH)')
pp.show()


pp.plot(snr_BBH.sample_times, abs(snr_BBH))
pp.ylabel('Signal-to-noise')
pp.xlabel('Time (s)')
pp.xlim(126,128)   
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Matched Filtered SNR-(Template-BBH)')
pp.show()
# Out:
# We found a signal at 127.800048828125s with SNR 13.28566534787726
# We found a signal at 126.999755859375s with SNR 6.836731054076408

# %% [markdown]
# # Chi-square Test

# %%
#Calculating the number of bins for chi-square for BNS And BBH signals


#BNS
k= 0.72*pycbc.pnutils.get_freq('fSEOBNRv4Peak',1.4,1.4,0.5,0.5)**0.7
print(int(k))

#BBH
z= 0.72*pycbc.pnutils.get_freq('fSEOBNRv4Peak',30,30,0.8,0.8)**0.7
print(int(z))
# Out:
# 265
# 33

# %%
def gen_chisquare(temp,data,n,psd):
    
   
    
    
    chisq = power_chisq(temp, data, n, psd=psd, low_frequency_cutoff=30.0)

    # convert to a reduced chisq
    chisq /= (n * 2) - 2
    
    
    
    pp.plot(chisq.sample_times, chisq)
    pp.ylabel('$\chi^2_r$')
    pp.xlabel('time (s)')
   
    
    
    return chisq


chisq_1 =  gen_chisquare(template,ts1,265,psd1)

pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Chisq w.r.t. BNS')
pp.show()



pp.plot(chisq_1.sample_times, chisq_1)
pp.ylabel('$\chi^2_r$')
pp.xlabel('time (s)')
pp.xlim(126,128) 
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Chisq w.r.t. BNS (zoomed)')
pp.show()

pp.plot(chisq_1.sample_times, chisq_1)
pp.ylabel('$\chi^2_r$')
pp.xlabel('time (s)')
pp.xlim(127.5,127.9) 
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.title('Chisq w.r.t. BNS(zoomed)')
pp.show()




chisq_2 =  gen_chisquare(temp_BBH,ts1,33,psd1)

pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Chisq w.r.t. BBH')
pp.show()



pp.plot(chisq_2.sample_times, chisq_2)
pp.ylabel('$\chi^2_r$')
pp.xlabel('time (s)')
pp.xlim(126.95,127.9)
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('Chisq w.r.t. BBH(zoomed)')
pp.show()

# %% [markdown]
# # Calculating the New SNR

# %%
nsnr1 = newsnr(abs(snr1),chisq_1)
nsnr2 = newsnr(abs(snr_BBH),chisq_2)


pp.plot(snr1.sample_times,nsnr1)
pp.ylabel('New Signal-to-noise Ratio')
pp.xlabel('Time (s)')
pp.xlim(126,128)
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('New SNR (BNS)')
pp.show()





pp.plot(snr_BBH.sample_times,nsnr2)
pp.ylabel('New Signal-to-noise Ratio')
pp.xlabel('Time (s)')
pp.xlim(126,128)
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.title('New SNR (BBH)')
pp.show()

# %% [markdown]
# # Plotting old and new(reweighed) SNR

# %%
pp.plot(snr1.sample_times,nsnr1,zorder=10,label='newsnr-BNS')
pp.plot(snr1.sample_times, abs(snr1),'-.',label='snr-BNS')
pp.legend()
pp.ylabel('Signal-to-noise Ratio')
pp.xlabel('Time (s)')
pp.xlim(126,128)
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.show()





pp.plot(snr_BBH.sample_times,nsnr2,zorder=10,label='newsnr-BBH')
pp.plot(snr_BBH.sample_times, abs(snr_BBH),'-.',label='snr-BBH')
pp.legend()
pp.ylabel('Signal-to-noise Ratio')
pp.xlabel('Time (s)')
pp.xlim(126,128)
pp.axvline(x=signal_1_peak,linestyle='-.',color='red',linewidth=1)
pp.axvline(x=signal_2_peak,linestyle='-.',color='green',linewidth=1)
pp.show()

# %% [markdown]
# ### Subtracting BBH Signal from data

# %%
h1_bbh.resize(len(ts1))
h1_bbh.start_time = ts1.start_time
ts2 = ts1 - h1_bbh
pp.plot(ts2.sample_times, ts2)
pp.xlabel('Time(s)')
pp.ylabel('Strain')
pp.grid()
pp.show()

# %%
psd2 = psd_data(ts2) #Calculating psd for case 2

# %%
snr2 = gen_SNR(template,ts2,psd2) #calculating snr for case 2
# Out:
# We found a signal at 127.800048828125s with SNR 13.291506783679129

# %%
#Calculating chisq


chisq_3=gen_chisquare(template,ts2,33,psd2)

pp.plot(chisq_3.sample_times, chisq_3)
pp.ylabel('$\chi^2_r$')
pp.xlabel('time (s)')
pp.xlim(127.5,128)
# Out:
# (127.5, 128.0)

# %%
#Calculating new snr


nsnr3=newsnr(abs(snr2),chisq_3)


pp.plot(snr2.sample_times,nsnr3,zorder=10,label='newsnr')
pp.plot(snr2.sample_times, abs(snr2),'-.',label='snr')
pp.legend()
pp.ylabel('Reweighted Signal-to-noise')
pp.xlabel('Time (s)')
pp.xlim(127,128)
pp.show()
